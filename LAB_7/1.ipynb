# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('heart_cleveland_upload.csv')

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
data = pd.get_dummies(data, columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal'])

# Normalize the continuous variables
continuous_vars = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
data[continuous_vars] = (data[continuous_vars] - data[continuous_vars].mean()) / data[continuous_vars].std()

# Split the data into training and testing sets

# %%
data# normalized data
# Out:
#           age  trestbps      chol   thalach   oldpeak  condition  sex_0  \
# 0    1.597606  1.593577 -0.256746 -0.810726 -0.819430          0      0
# 1    1.597606  0.467629 -0.160588  0.061054  0.638393          0      1
# 2    1.266105  1.030603 -0.410599 -1.551739  1.324427          0      1
# 3    1.155604  0.355034  0.666374  1.063601  0.295376          1      0
# 4    1.045104 -1.221294 -0.699074 -0.244069  0.638393          0      0
# ..        ...       ...       ...       ...       ...        ...    ...
# 292 -1.606907  1.143198 -0.468294  1.368724 -0.905184          1      0
# 293 -1.717408 -0.770914 -0.545221 -0.418425  0.123867          1      0
# 294 -2.159410 -0.658320 -0.949086 -0.854315  0.466884          1      0
# 295 -2.159410  0.355034 -1.237561  1.412313  0.295376          0      1
# 296 -2.159410 -0.320535  0.666374  0.278999 -0.905184          1      0
#
#      sex_1  cp_0  cp_1  ...  slope_0  slope_1  slope_2  ca_0  ca_1  ca_2  \
# ...

# %%
import numpy as np

data = pd.read_csv('heart.csv')

X = data[:, :-1]
y = data[:, -1]

def svm(X, y, C, epochs, learning_rate):
    # Initialize the weights and bias
    w = np.zeros(X.shape[1])
    b = 0

    for epoch in range(epochs):
        for i in range(X.shape[0]):
            margin = y[i] * (np.dot(w, X[i]) + b)

            if margin < 1:
                w = w - learning_rate * (2 * C * np.dot(w, X[i]) - y[i] * X[i])
                b = b - learning_rate * (-2 * C * y[i])
            else:
                w = w - learning_rate * 2 * C * np.dot(w, X[i])

    return w, b

C = 1
epochs = 1000
learning_rate = 0.01

# Train the SVM
w, b = svm(X, y, C, epochs, learning_rate)

# Print the weights and bias
print('Weights:', w) 
print('Bias:', b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-049592a1b83c> in <module>
#       5
#       6 # Split the data into features and labels
# ----> 7 X = data[:, :-1]
#       8 y = data[:, -1]
#       9
#
# c:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# ...

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit()
