# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('mushrooms.csv')

# %%
data['stalk-root']=data['stalk-root'].replace('?',np.nan)
data['stalk-root']=data['stalk-root'].fillna(np.nan,data['stalk-root'].mod()[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-808cb5e63220> in <module>
#       1 data['stalk-root']=data['stalk-root'].replace('?',np.nan)
# ----> 2 data['stalk-root']=data['stalk-root'].fillna(np.nan,data['stalk-root'].mod()[0])
#
# TypeError: flex_wrapper() missing 1 required positional argument: 'other'

# %%
for i in data.columns:
    print(i," " ,data[i].unique())
# Out:
# class   ['p' 'e']
# cap-shape   ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface   ['s' 'y' 'f' 'g']
# cap-color   ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises   ['t' 'f']
# odor   ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment   ['f' 'a']
# gill-spacing   ['c' 'w']
# gill-size   ['n' 'b']
# gill-color   ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape   ['e' 't']
# stalk-root   ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring   ['s' 'f' 'k' 'y']
# stalk-surface-below-ring   ['s' 'f' 'y' 'k']
# stalk-color-above-ring   ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring   ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type   ['p']
# veil-color   ['w' 'n' 'o' 'y']
# ring-number   ['o' 't' 'n']
# ring-type   ['p' 'e' 'l' 'f' 'n']
# spore-print-color   ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population   ['s' 'n' 'a' 'v' 'y' 'c']
# habitat   ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
data.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
objLE=LabelEncoder()

# %%
for i in data.columns:
    data[i]=objLE.fit_transform(data[i])

# %% [markdown]
# ## Poisonus ---> 1
# ## Ediable  ---> 0

# %%
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
data.to_csv('data_csv.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop(columns='class')
y=data['class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=10)

# %%
import numpy as np

def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2)**2))

class KNN:
    def __init__(self, k=3):
        self.k = k
        
    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
        
    def predict(self, X):
        y_pred = []
        for sample in X:
            distances = [euclidean_distance(sample, x) for x in self.X_train]
            indices = np.argsort(distances)[:self.k]
            k_nearest_labels = [self.y_train[i] for i in indices]
            most_common_label = max(set(k_nearest_labels), key=k_nearest_labels.count)
            y_pred.append(most_common_label)
        return y_pred

# %%
obj=KNN(5)
obj.fit(x_train,y_train)
y_pred=obj.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-e42777db00c2> in <module>
#       1 obj=KNN(5)
#       2 obj.fit(x_train,y_train)
# ----> 3 y_pred=obj.predict(x_test)
#
# <ipython-input-93-e88dd3c34775> in predict(self, X)
#      15         y_pred = []
#      16         for sample in X:
# ---> 17             distances = [euclidean_distance(sample, x) for x in self.X_train]
#      18             indices = np.argsort(distances)[:self.k]
#      19             k_nearest_labels = [self.y_train[i] for i in indices]
#
# <ipython-input-93-e88dd3c34775> in <listcomp>(.0)
#      15         y_pred = []
#      16         for sample in X:
# ---> 17             distances = [euclidean_distance(sample, x) for x in self.X_train]
#      18             indices = np.argsort(distances)[:self.k]
#      19             k_nearest_labels = [self.y_train[i] for i in indices]
#
# ...
